# %%
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
#import seaborn as sns

# %%
df=pd.read_csv

# %%
df = pd.read_csv('your_file.csv')
df.head()

# %%
import sys

print(sys.executable)
# Out:
# d:\PROJECTS\ML\Online_fraud_detection\.venv\Scripts\python.exe
